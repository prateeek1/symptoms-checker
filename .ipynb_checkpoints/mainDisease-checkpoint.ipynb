# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.utils import shuffle
from sklearn.preprocessing import MultiLabelBinarizer, LabelEncoder

# %%
df = pd.read_csv('dataset.csv')
df = shuffle(df, random_state = 42)
df.head()
# Out:
#                   Disease        Symptom_1            Symptom_2  \
# 373                  Acne        skin_rash           blackheads
# 4916                 Acne        skin_rash   pus_filled_pimples
# 1550      Hyperthyroidism          fatigue          mood_swings
# 3081                 AIDS   muscle_wasting    patches_in_throat
# 3857  Chronic cholestasis          itching             vomiting
#
#             Symptom_3                Symptom_4          Symptom_5  \
# 373          scurring                      NaN                NaN
# 4916       blackheads                 scurring                NaN
# 1550      weight_loss             restlessness           sweating
# 3081       high_fever   extra_marital_contacts                NaN
# 3857   yellowish_skin                   nausea   loss_of_appetite
#
#             Symptom_6           Symptom_7          Symptom_8  \
# 373               NaN                 NaN                NaN
# 4916              NaN                 NaN                NaN
# 1550        diarrhoea     fast_heart_rate   excessive_hunger
# 3081              NaN                 NaN                NaN
# 3857   abdominal_pain   yellowing_of_eyes                NaN
#
#              Symptom_9     Symptom_10              Symptom_11 Symptom_12  \
# 373                NaN            NaN                     NaN        NaN
# 4916               NaN            NaN                     NaN        NaN
# 1550   muscle_weakness   irritability   abnormal_menstruation        NaN
# 3081               NaN            NaN                     NaN        NaN
# 3857               NaN            NaN                     NaN        NaN
#
#      Symptom_13 Symptom_14 Symptom_15 Symptom_16 Symptom_17
# 373         NaN        NaN        NaN        NaN        NaN
# 4916        NaN        NaN        NaN        NaN        NaN
# 1550        NaN        NaN        NaN        NaN        NaN
# 3081        NaN        NaN        NaN        NaN        NaN
# 3857        NaN        NaN        NaN        NaN        NaN

# %%
# to Describe the dataset
df.describe()
# Out:
#                                         Disease  Symptom_1  Symptom_2  \
# count                                      4920       4920       4920
# unique                                       41         34         48
# top     (vertigo) Paroymsal  Positional Vertigo   vomiting   vomiting
# freq                                        120        822        870
#
#        Symptom_3    Symptom_4  Symptom_5 Symptom_6        Symptom_7  \
# count       4920         4572       3714      2934             2268
# unique        54           50         38        32               26
# top      fatigue   high_fever   headache    nausea   abdominal_pain
# freq         726          378        348       390              264
#
#               Symptom_8           Symptom_9          Symptom_10  \
# count              1944                1692                1512
# unique               21                  22                  21
# top      abdominal_pain   yellowing_of_eyes   yellowing_of_eyes
# freq                276                 228                 198
#
#            Symptom_11 Symptom_12    Symptom_13   Symptom_14   Symptom_15  \
# count            1194        744           504          306          240
# unique             18         11             8            4            3
# top      irritability    malaise   muscle_pain   chest_pain   chest_pain
# freq              120        126            72           96          144
#
#               Symptom_16    Symptom_17
# count                192            72
# unique                 3             1
# top      blood_in_sputum   muscle_pain
# freq                  72            72

# %% [markdown]
# #### ALL THE DIFFERENT TARGET VARIABLE

# %%
# all tagert variable 
li = df['Disease'].values.tolist()
li = set(li)
print(li)
# Out:
# {'Drug Reaction', 'GERD', 'Varicose veins', 'Hepatitis D', 'Hepatitis E', 'Hepatitis B', 'Hypothyroidism', 'Alcoholic hepatitis', 'Common Cold', 'Paralysis (brain hemorrhage)', 'Urinary tract infection', 'Cervical spondylosis', 'hepatitis A', 'Peptic ulcer diseae', 'Tuberculosis', 'Hyperthyroidism', 'Impetigo', 'AIDS', 'Hypoglycemia', 'Fungal infection', 'Jaundice', 'Typhoid', 'Psoriasis', 'Bronchial Asthma', 'Dengue', 'Pneumonia', 'Chicken pox', 'Acne', 'Malaria', 'Hypertension ', 'Heart attack', 'Arthritis', 'Migraine', 'Hepatitis C', 'Chronic cholestasis', 'Allergy', 'Diabetes ', 'Dimorphic hemmorhoids(piles)', 'Osteoarthristis', 'Gastroenteritis', '(vertigo) Paroymsal  Positional Vertigo'}

# %% [markdown]
# #FIND ALL NULL VALUES IN THE DATASET   >>
#
# <pre>these null value need to be handeled ->>
# in this case we can just replace null by 0 because the null value do not effect the prediction it will be teated as empty column<pre>

# %%
df.isnull().sum()
# Out:
# Disease          0
# Symptom_1        0
# Symptom_2        0
# Symptom_3        0
# Symptom_4      348
# Symptom_5     1206
# Symptom_6     1986
# Symptom_7     2652
# Symptom_8     2976
# Symptom_9     3228
# Symptom_10    3408
# Symptom_11    3726
# Symptom_12    4176
# Symptom_13    4416
# Symptom_14    4614
# Symptom_15    4680
# Symptom_16    4728
# Symptom_17    4848
# dtype: int64

# %%
# made changes in data 
for col in df.columns:
    df[col] = df[col].str.replace('_', ' ')

# %%
#to display all the values of the in bargraph we replace NaN with NULL str.....
# New Dataframe  
df2 = df.fillna("NULL")
df2.head()
# Out:
#                   Disease        Symptom_1            Symptom_2  \
# 373                  Acne        skin rash           blackheads
# 4916                 Acne        skin rash   pus filled pimples
# 1550      Hyperthyroidism          fatigue          mood swings
# 3081                 AIDS   muscle wasting    patches in throat
# 3857  Chronic cholestasis          itching             vomiting
#
#             Symptom_3                Symptom_4          Symptom_5  \
# 373          scurring                     NULL               NULL
# 4916       blackheads                 scurring               NULL
# 1550      weight loss             restlessness           sweating
# 3081       high fever   extra marital contacts               NULL
# 3857   yellowish skin                   nausea   loss of appetite
#
#             Symptom_6           Symptom_7          Symptom_8  \
# 373              NULL                NULL               NULL
# 4916             NULL                NULL               NULL
# 1550        diarrhoea     fast heart rate   excessive hunger
# 3081             NULL                NULL               NULL
# 3857   abdominal pain   yellowing of eyes               NULL
#
#              Symptom_9     Symptom_10              Symptom_11 Symptom_12  \
# 373               NULL           NULL                    NULL       NULL
# 4916              NULL           NULL                    NULL       NULL
# 1550   muscle weakness   irritability   abnormal menstruation       NULL
# 3081              NULL           NULL                    NULL       NULL
# 3857              NULL           NULL                    NULL       NULL
#
#      Symptom_13 Symptom_14 Symptom_15 Symptom_16 Symptom_17
# 373        NULL       NULL       NULL       NULL       NULL
# 4916       NULL       NULL       NULL       NULL       NULL
# 1550       NULL       NULL       NULL       NULL       NULL
# 3081       NULL       NULL       NULL       NULL       NULL
# 3857       NULL       NULL       NULL       NULL       NULL

# %%
# no of unique values ....
df.nunique(axis=0)
# Out:
# Disease       41
# Symptom_1     34
# Symptom_2     48
# Symptom_3     54
# Symptom_4     50
# Symptom_5     38
# Symptom_6     32
# Symptom_7     26
# Symptom_8     21
# Symptom_9     22
# Symptom_10    21
# Symptom_11    18
# Symptom_12    11
# Symptom_13     8
# Symptom_14     4
# Symptom_15     3
# Symptom_16     3
# Symptom_17     1
# dtype: int64

# %%
#print the unique values ....
for col in df.columns[1:]:
    print(col)
    print(df[col].unique())
# Out:
# Symptom_1
# [' skin rash' ' fatigue' ' muscle wasting' 'itching' ' headache'
#  ' vomiting' ' muscle weakness' ' acidity' ' burning micturition'
#  ' joint pain' ' constipation' ' back pain' ' continuous sneezing'
#  ' chills' ' chest pain' ' patches in throat' ' stomach pain' ' cramps'
#  ' weakness in limbs' ' cough' ' pus filled pimples' ' breathlessness'
#  ' sunken eyes' ' weight gain' ' pain during bowel movements' ' neck pain'
#  ' yellowish skin' ' stiff neck' ' mood swings' ' high fever'
#  ' bladder discomfort' ' shivering' ' indigestion' ' weight loss']
# Symptom_2
# [' blackheads' ' pus filled pimples' ' mood swings' ' patches in throat'
#  ' vomiting' ' chest pain' ' fatigue' ' stiff neck' ' indigestion'
#  ' bladder discomfort' ' weight loss' ' joint pain' ' yellowish skin'
#  ' pain during bowel movements' ' weakness in limbs' ' cough' ' shivering'
#  ' weight gain' ' dehydration' ' cramps' ' skin rash' ' headache'
#  ' dizziness' ' sunken eyes' ' breathlessness' ' chills' ' high fever'
#  ' cold hands and feets' ' acidity' ' nausea' ' bruising' ' anxiety'
#  ' skin peeling' ' neck pain' ' abdominal pain' ' lethargy' ' sweating'
#  ' weakness of one body side' ' pain in anal region' ' ulcers on tongue'
#  ' nodal skin eruptions' ' knee pain' ' swelling joints' ' blister'
#  ' foul smell of urine' ' stomach pain' ' restlessness'
#  ' loss of appetite']
# Symptom_3
# [' scurring' ' blackheads' ' weight loss' ' high fever' ' yellowish skin'
#  ' dizziness' ' anxiety' ' swelling joints' ' lethargy' ' headache'
#  ' foul smell of urine' ' restlessness' ' fatigue' ' skin peeling'
#  ' abdominal pain' ' pain in anal region' ' neck pain' ' chills' ' nausea'
#  ' cough' ' mood swings' ' diarrhoea' ' bruising' ' stomach pain'
#  ' loss of appetite' ' loss of balance' ' dehydration' ' sweating'
#  ' cold hands and feets' ' weakness of one body side'
#  ' extra marital contacts' ' nodal skin eruptions' ' blister'
#  ' ulcers on tongue' ' spinning movements' ' vomiting' ' joint pain'
#  ' obesity' ' silver like dusting' ' knee pain' ' swelling of stomach'
#  ' watering from eyes' ' breathlessness' ' continuous feel of urine'
#  ' chest pain' ' altered sensorium' ' bloody stool' ' movement stiffness'
#  ' dark urine' ' dischromic  patches' ' hip joint pain'
#  ' blurred and distorted vision' ' burning micturition'
#  ' red sore around nose']
# Symptom_4
# [nan ' scurring' ' restlessness' ' extra marital contacts' ' nausea'
#  ' loss of balance' ' sweating' ' painful walking' ' yellowish skin'
#  ' blurred and distorted vision' ' continuous feel of urine' ' lethargy'
#  ' small dents in nails' ' swelling of stomach' ' bloody stool'
#  ' high fever' ' dizziness' ' breathlessness' ' dark urine'
#  ' watering from eyes' ' loss of appetite' ' excessive hunger' ' obesity'
#  ' weight loss' ' burning micturition' ' yellowing of eyes'
#  ' spinning movements' ' lack of concentration' ' diarrhoea' ' headache'
#  ' silver like dusting' ' chest pain' ' cough' ' abdominal pain'
#  ' mood swings' ' altered sensorium' ' red sore around nose' ' vomiting'
#  ' fatigue' ' passage of gases' ' swollen legs' ' distention of abdomen'
#  ' movement stiffness' ' hip joint pain' ' irregular sugar level'
#  ' family history' ' dischromic  patches' ' swelling joints'
#  ' irritation in anus' ' spotting  urination' ' yellow crust ooze']
# Symptom_5
# [nan ' sweating' ' loss of appetite' ' lack of concentration' ' headache'
#  ' dark urine' ' excessive hunger' ' irregular sugar level'
#  ' inflammatory nails' ' distention of abdomen' ' irritation in anus'
#  ' yellowish skin' ' loss of balance' ' mucoid sputum' ' nausea'
#  ' family history' ' breathlessness' ' stiff neck' ' dizziness'
#  ' swollen legs' ' high fever' ' small dents in nails'
#  ' yellowing of eyes' ' passage of gases' ' unsteadiness' ' lethargy'
#  ' abdominal pain' ' yellow crust ooze' ' chest pain' ' cough'
#  ' spotting  urination' ' fatigue' ' internal itching'
#  ' swollen blood vessels' ' history of alcohol consumption'
#  ' painful walking' ' diarrhoea' ' swelling joints'
#  ' blurred and distorted vision']
# Symptom_6
# [nan ' diarrhoea' ' abdominal pain' ' nausea' ' loss of appetite'
#  ' stiff neck' ' blurred and distorted vision'
#  ' history of alcohol consumption' ' dark urine' ' mucoid sputum'
#  ' sweating' ' depression' ' puffy face and eyes'
#  ' prominent veins on calf' ' yellowish skin' ' unsteadiness'
#  ' inflammatory nails' ' breathlessness' ' swollen blood vessels'
#  ' family history' ' headache' ' dizziness' ' yellowing of eyes'
#  ' swelled lymph nodes' ' chest pain' ' high fever' ' fluid overload'
#  ' fast heart rate' ' painful walking' ' internal itching' ' obesity'
#  ' constipation' ' malaise']
# Symptom_7
# [nan ' fast heart rate' ' yellowing of eyes'
#  ' blurred and distorted vision' ' abdominal pain' ' depression'
#  ' obesity' ' loss of appetite' ' fluid overload' ' nausea'
#  ' excessive hunger' ' diarrhoea' ' malaise' ' irritability'
#  ' enlarged thyroid' ' dark urine' ' sweating' ' prominent veins on calf'
#  ' constipation' ' swelled lymph nodes' ' puffy face and eyes'
#  ' breathlessness' ' phlegm' ' muscle pain' ' mild fever' ' yellow urine'
#  ' headache']
# Symptom_8
# [nan ' excessive hunger' ' yellow urine' ' irritability' ' abdominal pain'
#  ' loss of appetite' ' increased appetite' ' mild fever' ' phlegm'
#  ' visual disturbances' ' brittle nails' ' drying and tingling lips'
#  ' malaise' ' muscle weakness' ' enlarged thyroid' ' muscle pain'
#  ' yellowing of eyes' ' sweating' ' chest pain' ' diarrhoea'
#  ' swelled lymph nodes' ' nausea']
# Symptom_9
# [nan ' muscle weakness' ' drying and tingling lips' ' yellowing of eyes'
#  ' visual disturbances' ' increased appetite' ' abdominal pain'
#  ' polyuria' ' chest pain' ' swollen extremeties' ' slurred speech'
#  ' mild fever' ' diarrhoea' ' phlegm' ' irritability' ' throat irritation'
#  ' pain behind the eyes' ' brittle nails' ' loss of appetite'
#  ' fast heart rate' ' swelled lymph nodes' ' toxic look (typhos)'
#  ' malaise']
# Symptom_10
# [nan ' irritability' ' slurred speech' ' malaise' ' polyuria'
#  ' yellowing of eyes' ' muscle pain' ' fast heart rate' ' depression'
#  ' acute liver failure' ' toxic look (typhos)' ' throat irritation'
#  ' abnormal menstruation' ' redness of eyes' ' back pain'
#  ' swollen extremeties' ' mild fever' ' rusty sputum' ' belly pain'
#  ' red spots over body' ' receiving blood transfusion'
#  ' pain behind the eyes']
# Symptom_11
# [nan ' abnormal menstruation' ' irritability'
#  ' receiving blood transfusion' ' acute liver failure' ' rusty sputum'
#  ' coma' ' palpitations' ' swelled lymph nodes' ' belly pain'
#  ' redness of eyes' ' sinus pressure' ' malaise' ' depression'
#  ' yellowing of eyes' ' red spots over body' ' muscle pain'
#  ' receiving unsterile injections' ' back pain']
# Symptom_12
# [nan ' palpitations' ' receiving unsterile injections' ' coma'
#  ' abnormal menstruation' ' stomach bleeding' ' malaise' ' sinus pressure'
#  ' runny nose' ' muscle pain' ' irritability' ' swelled lymph nodes']
# Symptom_13
# [nan ' stomach bleeding' ' phlegm' ' runny nose' ' congestion'
#  ' red spots over body' ' abnormal menstruation' ' malaise' ' muscle pain']
# Symptom_14
# [nan ' chest pain' ' congestion' ' phlegm' ' red spots over body']
# Symptom_15
# [nan ' blood in sputum' ' chest pain' ' loss of smell']
# Symptom_16
# [nan ' loss of smell' ' muscle pain' ' blood in sputum']
# Symptom_17
# [nan ' muscle pain']

# %% [markdown]
# #### PLOTTING ALL THE DIFFERENT SYMPTOMS UNIQUE ITEM COUNT
# (PS :: null repesent empty values)

# %%
#display all the symptons ......
for col in df2.columns[1:]:
    print(col)
    sns.catplot(x=col , kind="count",data=df2)
    plt.xticks(rotation='vertical')
    plt.show()
# Out:
# Symptom_1
# Symptom_2
# Symptom_3
# Symptom_4
# Symptom_5
# Symptom_6
# Symptom_7
# Symptom_8
# Symptom_9
# Symptom_10
# Symptom_11
# Symptom_12
# Symptom_13
# Symptom_14
# Symptom_15
# Symptom_16
# Symptom_17

# %%
df.describe()
# Out:
#                                         Disease  Symptom_1  Symptom_2  \
# count                                      4920       4920       4920
# unique                                       41         34         48
# top     (vertigo) Paroymsal  Positional Vertigo   vomiting   vomiting
# freq                                        120        822        870
#
#        Symptom_3    Symptom_4  Symptom_5 Symptom_6        Symptom_7  \
# count       4920         4572       3714      2934             2268
# unique        54           50         38        32               26
# top      fatigue   high fever   headache    nausea   abdominal pain
# freq         726          378        348       390              264
#
#               Symptom_8           Symptom_9          Symptom_10  \
# count              1944                1692                1512
# unique               21                  22                  21
# top      abdominal pain   yellowing of eyes   yellowing of eyes
# freq                276                 228                 198
#
#            Symptom_11 Symptom_12         Symptom_13   Symptom_14   Symptom_15  \
# count            1194        744                504          306          240
# unique             18         11                  8            4            3
# top      irritability    malaise   stomach bleeding   chest pain   chest pain
# freq              120        126                 72           96          144
#
#               Symptom_16    Symptom_17
# count                192            72
# unique                 3             1
# top      blood in sputum   muscle pain
# freq                  72            72

# %%
df.head()
# Out:
#                   Disease        Symptom_1            Symptom_2  \
# 373                  Acne        skin rash           blackheads
# 4916                 Acne        skin rash   pus filled pimples
# 1550      Hyperthyroidism          fatigue          mood swings
# 3081                 AIDS   muscle wasting    patches in throat
# 3857  Chronic cholestasis          itching             vomiting
#
#             Symptom_3                Symptom_4          Symptom_5  \
# 373          scurring                      NaN                NaN
# 4916       blackheads                 scurring                NaN
# 1550      weight loss             restlessness           sweating
# 3081       high fever   extra marital contacts                NaN
# 3857   yellowish skin                   nausea   loss of appetite
#
#             Symptom_6           Symptom_7          Symptom_8  \
# 373               NaN                 NaN                NaN
# 4916              NaN                 NaN                NaN
# 1550        diarrhoea     fast heart rate   excessive hunger
# 3081              NaN                 NaN                NaN
# 3857   abdominal pain   yellowing of eyes                NaN
#
#              Symptom_9     Symptom_10              Symptom_11 Symptom_12  \
# 373                NaN            NaN                     NaN        NaN
# 4916               NaN            NaN                     NaN        NaN
# 1550   muscle weakness   irritability   abnormal menstruation        NaN
# 3081               NaN            NaN                     NaN        NaN
# 3857               NaN            NaN                     NaN        NaN
#
#      Symptom_13 Symptom_14 Symptom_15 Symptom_16 Symptom_17
# 373         NaN        NaN        NaN        NaN        NaN
# 4916        NaN        NaN        NaN        NaN        NaN
# 1550        NaN        NaN        NaN        NaN        NaN
# 3081        NaN        NaN        NaN        NaN        NaN
# 3857        NaN        NaN        NaN        NaN        NaN

# %%
val = df.values

# %%
# from sklearn.preprocessing import LabelEncoder
# le = LabelEncoder()

# %%
# for col in df.columns:
#     df[col] = le.fit_transform(df[col].astype(str))

# %%
df.head()
# Out:
#                   Disease        Symptom_1            Symptom_2  \
# 373                  Acne        skin rash           blackheads
# 4916                 Acne        skin rash   pus filled pimples
# 1550      Hyperthyroidism          fatigue          mood swings
# 3081                 AIDS   muscle wasting    patches in throat
# 3857  Chronic cholestasis          itching             vomiting
#
#             Symptom_3                Symptom_4          Symptom_5  \
# 373          scurring                      NaN                NaN
# 4916       blackheads                 scurring                NaN
# 1550      weight loss             restlessness           sweating
# 3081       high fever   extra marital contacts                NaN
# 3857   yellowish skin                   nausea   loss of appetite
#
#             Symptom_6           Symptom_7          Symptom_8  \
# 373               NaN                 NaN                NaN
# 4916              NaN                 NaN                NaN
# 1550        diarrhoea     fast heart rate   excessive hunger
# 3081              NaN                 NaN                NaN
# 3857   abdominal pain   yellowing of eyes                NaN
#
#              Symptom_9     Symptom_10              Symptom_11 Symptom_12  \
# 373                NaN            NaN                     NaN        NaN
# 4916               NaN            NaN                     NaN        NaN
# 1550   muscle weakness   irritability   abnormal menstruation        NaN
# 3081               NaN            NaN                     NaN        NaN
# 3857               NaN            NaN                     NaN        NaN
#
#      Symptom_13 Symptom_14 Symptom_15 Symptom_16 Symptom_17
# 373         NaN        NaN        NaN        NaN        NaN
# 4916        NaN        NaN        NaN        NaN        NaN
# 1550        NaN        NaN        NaN        NaN        NaN
# 3081        NaN        NaN        NaN        NaN        NaN
# 3857        NaN        NaN        NaN        NaN        NaN

# %%
y = df.drop('Disease', axis=1)

# %% [markdown]
# ### creating dummies
# <br/>of the cagorical variable and the conacatinate data with main dataframe

# %%
y = pd.get_dummies(y)

# %%
# symptoms = []

# for col in df.columns[1:]:
#     symptoms.append(df[col].unique())

# symptoms

# %%
y.head()
# Out:
#       Symptom_1_ acidity  Symptom_1_ back pain  Symptom_1_ bladder discomfort  \
# 373                    0                     0                              0
# 4916                   0                     0                              0
# 1550                   0                     0                              0
# 3081                   0                     0                              0
# 3857                   0                     0                              0
#
#       Symptom_1_ breathlessness  Symptom_1_ burning micturition  \
# 373                           0                               0
# 4916                          0                               0
# 1550                          0                               0
# 3081                          0                               0
# 3857                          0                               0
#
#       Symptom_1_ chest pain  Symptom_1_ chills  Symptom_1_ constipation  \
# 373                       0                  0                        0
# 4916                      0                  0                        0
# 1550                      0                  0                        0
# 3081                      0                  0                        0
# 3857                      0                  0                        0
#
#       Symptom_1_ continuous sneezing  Symptom_1_ cough  ...  \
# 373                                0                 0  ...
# 4916                               0                 0  ...
# 1550                               0                 0  ...
# 3081                               0                 0  ...
# 3857                               0                 0  ...
#
#       Symptom_14_ congestion  Symptom_14_ phlegm  \
# 373                        0                   0
# 4916                       0                   0
# 1550                       0                   0
# 3081                       0                   0
# 3857                       0                   0
#
#       Symptom_14_ red spots over body  Symptom_15_ blood in sputum  \
# 373                                 0                            0
# 4916                                0                            0
# 1550                                0                            0
# 3081                                0                            0
# 3857                                0                            0
#
#       Symptom_15_ chest pain  Symptom_15_ loss of smell  \
# 373                        0                          0
# 4916                       0                          0
# 1550                       0                          0
# 3081                       0                          0
# 3857                       0                          0
#
#       Symptom_16_ blood in sputum  Symptom_16_ loss of smell  \
# 373                             0                          0
# 4916                            0                          0
# 1550                            0                          0
# 3081                            0                          0
# 3857                            0                          0
#
#       Symptom_16_ muscle pain  Symptom_17_ muscle pain
# 373                         0                        0
# 4916                        0                        0
# 1550                        0                        0
# 3081                        0                        0
# 3857                        0                        0
#
# [5 rows x 394 columns]

# %% [markdown]
# #### There are many commmon columns we need to merge

# %%
for col in y.columns:
    j = col.split('_')[-1]
    y =y.rename(columns={col:j})
    # print(col," ",j)

# %%
y.columns.value_counts()
# we have same columns ....
# Out:
#  chest pain               10
#  yellowing of eyes         8
#  malaise                   8
#  muscle pain               8
#  loss of appetite          8
#                           ..
#  knee pain                 2
#  distention of abdomen     2
# itching                    1
#  continuous sneezing       1
#  muscle wasting            1
# Length: 131, dtype: int64

# %% [markdown]
# ##### grouping column of same name

# %%
y=y.groupby(level=0, axis=1).sum()

# %%
y.head()
# Out:
#        abdominal pain   abnormal menstruation   acidity   acute liver failure  \
# 373                 0                       0         0                     0
# 4916                0                       0         0                     0
# 1550                0                       1         0                     0
# 3081                0                       0         0                     0
# 3857                1                       0         0                     0
#
#        altered sensorium   anxiety   back pain   belly pain   blackheads  \
# 373                    0         0           0            0            1
# 4916                   0         0           0            0            1
# 1550                   0         0           0            0            0
# 3081                   0         0           0            0            0
# 3857                   0         0           0            0            0
#
#        bladder discomfort  ...   watering from eyes   weakness in limbs  \
# 373                     0  ...                    0                   0
# 4916                    0  ...                    0                   0
# 1550                    0  ...                    0                   0
# 3081                    0  ...                    0                   0
# 3857                    0  ...                    0                   0
#
#        weakness of one body side   weight gain   weight loss  \
# 373                            0             0             0
# 4916                           0             0             0
# 1550                           0             0             1
# 3081                           0             0             0
# 3857                           0             0             0
#
#        yellow crust ooze   yellow urine   yellowing of eyes   yellowish skin  \
# 373                    0              0                   0                0
# 4916                   0              0                   0                0
# 1550                   0              0                   0                0
# 3081                   0              0                   0                0
# 3857                   0              0                   1                1
#
#       itching
# 373         0
# 4916        0
# 1550        0
# 3081        0
# 3857        1
#
# [5 rows x 131 columns]

# %%
x = df['Disease']

# %%
x.shape
# Out:
# (4920,)

# %%
y.shape
# Out:
# (4920, 131)

# %%
y.isnull().sum()
# 0 null values 
# only 2 posible binary options of the dataframe featues YES /NO
# Out:
#  abdominal pain           0
#  abnormal menstruation    0
#  acidity                  0
#  acute liver failure      0
#  altered sensorium        0
#                          ..
#  yellow crust ooze        0
#  yellow urine             0
#  yellowing of eyes        0
#  yellowish skin           0
# itching                   0
# Length: 131, dtype: int64

# %%
for col in y.columns[1:]:
    print(col)
    sns.catplot(x=col , kind="count",data=y)
    plt.xticks(rotation='vertical')
    plt.show()
# Out:
#  abnormal menstruation
#  acidity
#  acute liver failure
#  altered sensorium
#  anxiety
#  back pain
#  belly pain
#  blackheads
#  bladder discomfort
#  blister
#  blood in sputum
#  bloody stool
#  blurred and distorted vision
#  breathlessness
#  brittle nails
#  bruising
#  burning micturition
#  chest pain
#  chills
#  cold hands and feets
#  coma
#  congestion
#  constipation
#  continuous feel of urine
#  continuous sneezing
#  cough
#  cramps
#  dark urine
#  dehydration
#  depression
#  diarrhoea
#  dischromic  patches
#  distention of abdomen
#  dizziness
#  drying and tingling lips
#  enlarged thyroid
#  excessive hunger
#  extra marital contacts
#  family history
#  fast heart rate
#  fatigue
#  fluid overload
#  foul smell of urine
#  headache
#  high fever
#  hip joint pain
#  history of alcohol consumption
#  increased appetite
#  indigestion
#  inflammatory nails
#  internal itching
#  irregular sugar level
#  irritability
#  irritation in anus
#  joint pain
#  knee pain
#  lack of concentration
#  lethargy
#  loss of appetite
#  loss of balance
#  loss of smell
#  malaise
#  mild fever
#  mood swings
#  movement stiffness
#  mucoid sputum
#  muscle pain
#  muscle wasting
#  muscle weakness
#  nausea
#  neck pain
#  nodal skin eruptions
#  obesity
#  pain behind the eyes
#  pain during bowel movements
#  pain in anal region
#  painful walking
#  palpitations
#  passage of gases
#  patches in throat
#  phlegm
#  polyuria
#  prominent veins on calf
#  puffy face and eyes
#  pus filled pimples
#  receiving blood transfusion
#  receiving unsterile injections
#  red sore around nose
#  red spots over body
#  redness of eyes
#  restlessness
#  runny nose
#  rusty sputum
#  scurring
#  shivering
#  silver like dusting
#  sinus pressure
#  skin peeling
#  skin rash
#  slurred speech
#  small dents in nails
#  spinning movements
#  spotting  urination
#  stiff neck
#  stomach bleeding
#  stomach pain
#  sunken eyes
#  sweating
#  swelled lymph nodes
#  swelling joints
#  swelling of stomach
#  swollen blood vessels
#  swollen extremeties
#  swollen legs
#  throat irritation
#  toxic look (typhos)
#  ulcers on tongue
#  unsteadiness
#  visual disturbances
#  vomiting
#  watering from eyes
#  weakness in limbs
#  weakness of one body side
#  weight gain
#  weight loss
#  yellow crust ooze
#  yellow urine
#  yellowing of eyes
#  yellowish skin
# itching

# %%
y['Disease']=df.Disease

# %%
y.to_csv('pre_processed.csv',index=False)

# %%
y.corr()
# Out:
#                          abdominal pain   abnormal menstruation   acidity  \
#  abdominal pain                1.000000               -0.116670 -0.111995
#  abnormal menstruation        -0.116670                1.000000 -0.049227
#  acidity                      -0.111995               -0.049227  1.000000
#  acute liver failure           0.298940               -0.034877 -0.033480
#  altered sensorium            -0.079348               -0.034877 -0.033480
# ...                                 ...                     ...       ...
#  yellow crust ooze            -0.079348               -0.034877 -0.033480
#  yellow urine                  0.279030               -0.034877 -0.033480
#  yellowing of eyes             0.527264               -0.100977 -0.096931
#  yellowish skin                0.733180               -0.108023 -0.103694
# itching                        0.263282               -0.090534 -0.086906
#
#                          acute liver failure   altered sensorium   anxiety  \
#  abdominal pain                     0.298940           -0.079348 -0.079348
#  abnormal menstruation             -0.034877           -0.034877 -0.034877
#  acidity                           -0.033480           -0.033480 -0.033480
#  acute liver failure                1.000000           -0.023720 -0.023720
#  altered sensorium                 -0.023720            1.000000 -0.023720
# ...                                      ...                 ...       ...
#  yellow crust ooze                 -0.023720           -0.023720 -0.023720
#  yellow urine                      -0.023720           -0.023720 -0.023720
#  yellowing of eyes                  0.345397           -0.068676 -0.068676
#  yellowish skin                     0.302010           -0.073467 -0.073467
# itching                            -0.061573           -0.061573 -0.061573
#
#                          back pain   belly pain   blackheads  \
#  abdominal pain          -0.113570     0.279030    -0.077184
#  abnormal menstruation   -0.049920    -0.034877    -0.033926
#  acidity                 -0.047919    -0.033480    -0.032566
#  acute liver failure     -0.033951    -0.023720    -0.023073
#  altered sensorium       -0.033951    -0.023720    -0.023073
# ...                            ...          ...          ...
#  yellow crust ooze       -0.033951    -0.023720    -0.023073
#  yellow urine            -0.033951    -0.023720    -0.023073
#  yellowing of eyes       -0.098295    -0.068676    -0.066802
#  yellowish skin          -0.105153    -0.073467    -0.071463
# itching                  -0.088129    -0.061573    -0.059893
#
#                          bladder discomfort  ...   watering from eyes  \
#  abdominal pain                   -0.079348  ...            -0.077184
#  abnormal menstruation            -0.034877  ...            -0.033926
#  acidity                          -0.033480  ...            -0.032566
#  acute liver failure              -0.023720  ...            -0.023073
#  altered sensorium                -0.023720  ...            -0.023073
# ...                                     ...  ...                  ...
#  yellow crust ooze                -0.023720  ...            -0.023073
#  yellow urine                     -0.023720  ...            -0.023073
#  yellowing of eyes                -0.068676  ...            -0.066802
#  yellowish skin                   -0.073467  ...            -0.071463
# itching                           -0.061573  ...            -0.059893
#
#                          weakness in limbs   weakness of one body side  \
#  abdominal pain                  -0.077184                   -0.077184
#  abnormal menstruation           -0.033926                   -0.033926
#  acidity                         -0.032566                   -0.032566
#  acute liver failure             -0.023073                   -0.023073
#  altered sensorium               -0.023073                    0.917400
# ...                                    ...                         ...
#  yellow crust ooze               -0.023073                   -0.023073
#  yellow urine                    -0.023073                   -0.023073
#  yellowing of eyes               -0.066802                   -0.066802
#  yellowish skin                  -0.071463                   -0.071463
# itching                          -0.059893                   -0.059893
#
#                          weight gain   weight loss   yellow crust ooze  \
#  abdominal pain            -0.079348      0.021263           -0.079348
#  abnormal menstruation      0.680108      0.298557           -0.034877
#  acidity                   -0.033480     -0.069477           -0.033480
#  acute liver failure       -0.023720     -0.049224           -0.023720
#  altered sensorium         -0.023720     -0.049224           -0.023720
# ...                              ...           ...                 ...
#  yellow crust ooze         -0.023720     -0.049224            1.000000
#  yellow urine              -0.023720     -0.049224           -0.023720
#  yellowing of eyes         -0.068676      0.072306           -0.068676
#  yellowish skin            -0.073467      0.042338           -0.073467
# itching                    -0.061573      0.091830           -0.061573
#
#                          yellow urine   yellowing of eyes   yellowish skin  \
#  abdominal pain              0.279030            0.527264         0.733180
#  abnormal menstruation      -0.034877           -0.100977        -0.108023
#  acidity                    -0.033480           -0.096931        -0.103694
#  acute liver failure        -0.023720            0.345397         0.302010
#  altered sensorium          -0.023720           -0.068676        -0.073467
# ...                               ...                 ...              ...
#  yellow crust ooze          -0.023720           -0.068676        -0.073467
#  yellow urine                1.000000            0.345397         0.302010
#  yellowing of eyes           0.345397            1.000000         0.715405
#  yellowish skin              0.302010            0.715405         1.000000
# itching                      0.361723            0.173673         0.300936
#
#                          itching
#  abdominal pain         0.263282
#  abnormal menstruation -0.090534
#  acidity               -0.086906
#  acute liver failure   -0.061573
#  altered sensorium     -0.061573
# ...                          ...
#  yellow crust ooze     -0.061573
#  yellow urine           0.361723
#  yellowing of eyes      0.173673
#  yellowish skin         0.300936
# itching                 1.000000
#
# [131 rows x 131 columns]

# %%
plt.figure(figsize=(50,50))
sns.heatmap(y.corr(), cmap="YlGnBu", annot=True)
plt.show()
